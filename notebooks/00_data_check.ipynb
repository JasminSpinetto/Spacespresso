# %% [markdown]
# # Data Check
#
# Lightweight dataset inspection. Shared logic lives in `src/`.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.common.config import load_config
from src.common.data import SpacepressoDataModule
from src.common.visualization import show_samples

# %%
config = load_config(ROOT / "configs/patchcore_lite/juan_baseline.yaml")
dm = SpacepressoDataModule(**config["data"])

print("classes:", dm.list_classes())
train_good = dm.load_train_good()
train_anomalies = dm.load_train_anomalies()
test = dm.load_test()

print("train_good:", len(train_good))
print("train_anomalies:", len(train_anomalies))
print("test:", len(test))
print("anomaly descriptions:", None if dm.load_anomaly_descriptions() is None else dm.load_anomaly_descriptions().shape)

# %%
show_samples(train_good, n=5)
