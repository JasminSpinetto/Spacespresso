# %% [markdown]
# # Validation Rankings

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.common.ranking import load_rankings

# %%
rankings = load_rankings(ROOT)
rankings
# Out:
#     rank                              model_id  \
# 0      1   patchcore_lite_juan_full_trial_0002
# 1      2   patchcore_lite_juan_full_trial_0006
# 2      3   patchcore_lite_juan_full_trial_0007
# 3      4   patchcore_lite_juan_full_trial_0001
# 4      5               patchcore_lite_baseline
# 5      6        patchcore_lite_juan_trial_0004
# 6      7   patchcore_lite_juan_full_trial_0003
# 7      8   patchcore_lite_juan_full_trial_0000
# 8      9        patchcore_lite_juan_trial_0009
# 9     10        patchcore_lite_juan_trial_0003
# 10    11   patchcore_lite_juan_full_trial_0005
# 11    12        patchcore_lite_juan_trial_0006
# 12    13   patchcore_lite_juan_full_trial_0008
# 13    14   patchcore_lite_juan_full_trial_0009
# 14    15        patchcore_lite_juan_trial_0007
# 15    16        patchcore_lite_juan_trial_0005
# 16    17        patchcore_lite_juan_trial_0001
# 17    18        patchcore_lite_juan_trial_0008
# 18    19        patchcore_lite_juan_trial_0000
# 19    20        patchcore_lite_juan_trial_0002
# 20    21   patchcore_lite_juan_full_trial_0004
# 21    22  patchcore_lite_juan_debug_trial_0000
#
#                          experiment_name      parent_experiment owner  \
# 0    patchcore_lite_juan_full_trial_0002  patchcore_lite_tuning  juan
# 1    patchcore_lite_juan_full_trial_0006  patchcore_lite_tuning  juan
# 2    patchcore_lite_juan_full_trial_0007  patchcore_lite_tuning  juan
# 3    patchcore_lite_juan_full_trial_0001  patchcore_lite_tuning  juan
# 4                patchcore_lite_baseline                    NaN  juan
# 5         patchcore_lite_juan_trial_0004  patchcore_lite_tuning  juan
# 6    patchcore_lite_juan_full_trial_0003  patchcore_lite_tuning  juan
# 7    patchcore_lite_juan_full_trial_0000  patchcore_lite_tuning  juan
# 8         patchcore_lite_juan_trial_0009  patchcore_lite_tuning  juan
# 9         patchcore_lite_juan_trial_0003  patchcore_lite_tuning  juan
# 10   patchcore_lite_juan_full_trial_0005  patchcore_lite_tuning  juan
# 11        patchcore_lite_juan_trial_0006  patchcore_lite_tuning  juan
# 12   patchcore_lite_juan_full_trial_0008  patchcore_lite_tuning  juan
# 13   patchcore_lite_juan_full_trial_0009  patchcore_lite_tuning  juan
# 14        patchcore_lite_juan_trial_0007  patchcore_lite_tuning  juan
# 15        patchcore_lite_juan_trial_0005  patchcore_lite_tuning  juan
# 16        patchcore_lite_juan_trial_0001  patchcore_lite_tuning  juan
# 17        patchcore_lite_juan_trial_0008  patchcore_lite_tuning  juan
# 18        patchcore_lite_juan_trial_0000  patchcore_lite_tuning  juan
# 19        patchcore_lite_juan_trial_0002  patchcore_lite_tuning  juan
# 20   patchcore_lite_juan_full_trial_0004  patchcore_lite_tuning  juan
# 21  patchcore_lite_juan_debug_trial_0000  patchcore_lite_tuning  juan
#
#             method    source    metric     score  pixel_ap  ...  n_images  \
# 0   patchcore_lite    optuna  pixel_ap  0.339805  0.339805  ...      1190
# 1   patchcore_lite    optuna  pixel_ap  0.335808  0.335808  ...      1190
# 2   patchcore_lite    optuna  pixel_ap  0.334006  0.334006  ...      1190
# 3   patchcore_lite    optuna  pixel_ap  0.323102  0.323102  ...      1190
# 4   patchcore_lite  baseline  pixel_ap  0.322563  0.322563  ...      1190
# 5   patchcore_lite    optuna  pixel_ap  0.322267  0.322267  ...      1190
# 6   patchcore_lite    optuna  pixel_ap  0.321557  0.321557  ...      1190
# 7   patchcore_lite    optuna  pixel_ap  0.319819  0.319819  ...      1190
# 8   patchcore_lite    optuna  pixel_ap  0.314869  0.314869  ...      1190
# 9   patchcore_lite    optuna  pixel_ap  0.313526  0.313526  ...      1190
# 10  patchcore_lite    optuna  pixel_ap  0.313185  0.313185  ...      1190
# 11  patchcore_lite    optuna  pixel_ap  0.312060  0.312060  ...      1190
# 12  patchcore_lite    optuna  pixel_ap  0.311531  0.311531  ...      1190
# 13  patchcore_lite    optuna  pixel_ap  0.311027  0.311027  ...      1190
# 14  patchcore_lite    optuna  pixel_ap  0.308948  0.308948  ...      1190
# 15  patchcore_lite    optuna  pixel_ap  0.305698  0.305698  ...      1190
# 16  patchcore_lite    optuna  pixel_ap  0.304889  0.304889  ...      1190
# 17  patchcore_lite    optuna  pixel_ap  0.304730  0.304730  ...      1190
# 18  patchcore_lite    optuna  pixel_ap  0.303279  0.303279  ...      1190
# 19  patchcore_lite    optuna  pixel_ap  0.300540  0.300540  ...      1190
# 20  patchcore_lite    optuna  pixel_ap  0.299967  0.299967  ...      1190
# 21  patchcore_lite    optuna  pixel_ap  0.240602  0.240602  ...        62
#
#     n_anomaly_pixels  validation_n_splits  validation_folds  \
# 0            1217489                    5                 0
# 1            1217489                    5                 0
# 2            1217489                    5                 0
# 3            1217489                    5                 0
# 4            1217489                    5                 0
# 5            1217489                    5                 0
# 6            1217489                    5                 0
# 7            1217489                    5                 0
# 8            1217489                    5                 0
# 9            1217489                    5                 0
# 10           1217489                    5                 0
# 11           1217489                    5                 0
# 12           1217489                    5                 0
# 13           1217489                    5                 0
# 14           1217489                    5                 0
# 15           1217489                    5                 0
# 16           1217489                    5                 0
# 17           1217489                    5                 0
# 18           1217489                    5                 0
# 19           1217489                    5                 0
# 20           1217489                    5                 0
# 21            340584                    2                 0
#
#     validation_good_fraction  validation_anomaly_fraction  \
# 0                       0.25                          1.0
# 1                       0.25                          1.0
# 2                       0.25                          1.0
# 3                       0.25                          1.0
# 4                       0.25                          1.0
# 5                       0.25                          1.0
# 6                       0.25                          1.0
# 7                       0.25                          1.0
# 8                       0.25                          1.0
# 9                       0.25                          1.0
# 10                      0.25                          1.0
# 11                      0.25                          1.0
# 12                      0.25                          1.0
# 13                      0.25                          1.0
# 14                      0.25                          1.0
# 15                      0.25                          1.0
# 16                      0.25                          1.0
# 17                      0.25                          1.0
# 18                      0.25                          1.0
# 19                      0.25                          1.0
# 20                      0.25                          1.0
# 21                      0.25                          1.0
#
#                                           config_path  \
# 0   outputs\juan\patchcore_lite_tuning\full_optuna...
# 1   outputs\juan\patchcore_lite_tuning\full_optuna...
# 2   outputs\juan\patchcore_lite_tuning\full_optuna...
# 3   outputs\juan\patchcore_lite_tuning\full_optuna...
# 4           configs\patchcore_lite\juan_baseline.yaml
# 5   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 6   outputs\juan\patchcore_lite_tuning\full_optuna...
# 7   outputs\juan\patchcore_lite_tuning\full_optuna...
# 8   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 9   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 10  outputs\juan\patchcore_lite_tuning\full_optuna...
# 11  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 12  outputs\juan\patchcore_lite_tuning\full_optuna...
# 13  outputs\juan\patchcore_lite_tuning\full_optuna...
# 14  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 15  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 16  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 17  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 18  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 19  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 20  outputs\juan\patchcore_lite_tuning\full_optuna...
# 21  outputs\juan\patchcore_lite_tuning\debug_optun...
#
#                                           params_json  \
# 0   {"candidate_pool_size": 6000, "coreset_fractio...
# 1   {"candidate_pool_size": 7000, "coreset_fractio...
# 2   {"candidate_pool_size": 5000, "coreset_fractio...
# 3   {"candidate_pool_size": 7000, "coreset_fractio...
# 4   {"backbone": "wide_resnet50_2", "bank_chunk_si...
# 5   {"candidate_pool_size": 4000, "coreset_fractio...
# 6   {"candidate_pool_size": 5000, "coreset_fractio...
# 7   {"candidate_pool_size": 6000, "coreset_fractio...
# 8   {"candidate_pool_size": 5000, "coreset_fractio...
# 9   {"candidate_pool_size": 6000, "coreset_fractio...
# 10  {"candidate_pool_size": 8000, "coreset_fractio...
# 11  {"candidate_pool_size": 4000, "coreset_fractio...
# 12  {"candidate_pool_size": 5000, "coreset_fractio...
# 13  {"candidate_pool_size": 3000, "coreset_fractio...
# 14  {"candidate_pool_size": 5000, "coreset_fractio...
# 15  {"candidate_pool_size": 4000, "coreset_fractio...
# 16  {"candidate_pool_size": 5000, "coreset_fractio...
# 17  {"candidate_pool_size": 2000, "coreset_fractio...
# 18  {"candidate_pool_size": 5000, "coreset_fractio...
# 19  {"candidate_pool_size": 2000, "coreset_fractio...
# 20  {"candidate_pool_size": 4000, "coreset_fractio...
# 21  {"candidate_pool_size": 6000, "coreset_fractio...
#
#                                  notes                        created_at
# 0                       Optuna trial 2  2026-05-10T16:55:35.536978+00:00
# 1                       Optuna trial 6  2026-05-10T16:55:35.536978+00:00
# 2                       Optuna trial 7  2026-05-10T16:55:35.536978+00:00
# 3                       Optuna trial 1  2026-05-10T16:55:35.536978+00:00
# 4   PatchCore Lite baseline validation  2026-05-07T12:46:02.757469+00:00
# 5                       Optuna trial 4  2026-05-07T13:10:57.233644+00:00
# 6                       Optuna trial 3  2026-05-10T16:55:35.536978+00:00
# 7                       Optuna trial 0  2026-05-10T16:55:35.536978+00:00
# 8                       Optuna trial 9  2026-05-07T13:10:57.233644+00:00
# 9                       Optuna trial 3  2026-05-07T13:10:57.233644+00:00
# 10                      Optuna trial 5  2026-05-10T16:55:35.536978+00:00
# 11                      Optuna trial 6  2026-05-07T13:10:57.233644+00:00
# 12                      Optuna trial 8  2026-05-10T16:55:35.536978+00:00
# 13                      Optuna trial 9  2026-05-10T16:55:35.536978+00:00
# 14                      Optuna trial 7  2026-05-07T13:10:57.233644+00:00
# 15                      Optuna trial 5  2026-05-07T13:10:57.233644+00:00
# 16                      Optuna trial 1  2026-05-07T13:10:57.233644+00:00
# 17                      Optuna trial 8  2026-05-07T13:10:57.233644+00:00
# 18                      Optuna trial 0  2026-05-07T13:10:57.233644+00:00
# 19                      Optuna trial 2  2026-05-07T13:10:57.233644+00:00
# 20                      Optuna trial 4  2026-05-10T16:55:35.536978+00:00
# 21                      Optuna trial 0  2026-05-10T15:44:18.906969+00:00
#
# [22 rows x 23 columns]

# %%
columns = [
    "rank",
    "model_id",
    "owner",
    "method",
    "source",
    "metric",
    "score",
    "pixel_ap",
    "image_ap",
    "config_path",
]
rankings[[c for c in columns if c in rankings.columns]].head(50)
# Out:
#     rank                              model_id owner          method  \
# 0      1   patchcore_lite_juan_full_trial_0002  juan  patchcore_lite
# 1      2   patchcore_lite_juan_full_trial_0006  juan  patchcore_lite
# 2      3   patchcore_lite_juan_full_trial_0007  juan  patchcore_lite
# 3      4   patchcore_lite_juan_full_trial_0001  juan  patchcore_lite
# 4      5               patchcore_lite_baseline  juan  patchcore_lite
# 5      6        patchcore_lite_juan_trial_0004  juan  patchcore_lite
# 6      7   patchcore_lite_juan_full_trial_0003  juan  patchcore_lite
# 7      8   patchcore_lite_juan_full_trial_0000  juan  patchcore_lite
# 8      9        patchcore_lite_juan_trial_0009  juan  patchcore_lite
# 9     10        patchcore_lite_juan_trial_0003  juan  patchcore_lite
# 10    11   patchcore_lite_juan_full_trial_0005  juan  patchcore_lite
# 11    12        patchcore_lite_juan_trial_0006  juan  patchcore_lite
# 12    13   patchcore_lite_juan_full_trial_0008  juan  patchcore_lite
# 13    14   patchcore_lite_juan_full_trial_0009  juan  patchcore_lite
# 14    15        patchcore_lite_juan_trial_0007  juan  patchcore_lite
# 15    16        patchcore_lite_juan_trial_0005  juan  patchcore_lite
# 16    17        patchcore_lite_juan_trial_0001  juan  patchcore_lite
# 17    18        patchcore_lite_juan_trial_0008  juan  patchcore_lite
# 18    19        patchcore_lite_juan_trial_0000  juan  patchcore_lite
# 19    20        patchcore_lite_juan_trial_0002  juan  patchcore_lite
# 20    21   patchcore_lite_juan_full_trial_0004  juan  patchcore_lite
# 21    22  patchcore_lite_juan_debug_trial_0000  juan  patchcore_lite
#
#       source    metric     score  pixel_ap  image_ap  \
# 0     optuna  pixel_ap  0.339805  0.339805  0.605379
# 1     optuna  pixel_ap  0.335808  0.335808  0.606024
# 2     optuna  pixel_ap  0.334006  0.334006  0.602076
# 3     optuna  pixel_ap  0.323102  0.323102  0.606527
# 4   baseline  pixel_ap  0.322563  0.322563  0.581574
# 5     optuna  pixel_ap  0.322267  0.322267  0.576375
# 6     optuna  pixel_ap  0.321557  0.321557  0.570524
# 7     optuna  pixel_ap  0.319819  0.319819  0.578419
# 8     optuna  pixel_ap  0.314869  0.314869  0.573433
# 9     optuna  pixel_ap  0.313526  0.313526  0.576634
# 10    optuna  pixel_ap  0.313185  0.313185  0.590549
# 11    optuna  pixel_ap  0.312060  0.312060  0.563686
# 12    optuna  pixel_ap  0.311531  0.311531  0.589024
# 13    optuna  pixel_ap  0.311027  0.311027  0.547005
# 14    optuna  pixel_ap  0.308948  0.308948  0.569556
# 15    optuna  pixel_ap  0.305698  0.305698  0.566320
# 16    optuna  pixel_ap  0.304889  0.304889  0.562586
# 17    optuna  pixel_ap  0.304730  0.304730  0.537169
# 18    optuna  pixel_ap  0.303279  0.303279  0.570097
# 19    optuna  pixel_ap  0.300540  0.300540  0.542079
# 20    optuna  pixel_ap  0.299967  0.299967  0.556124
# 21    optuna  pixel_ap  0.240602  0.240602  0.650185
#
#                                           config_path
# 0   outputs\juan\patchcore_lite_tuning\full_optuna...
# 1   outputs\juan\patchcore_lite_tuning\full_optuna...
# 2   outputs\juan\patchcore_lite_tuning\full_optuna...
# 3   outputs\juan\patchcore_lite_tuning\full_optuna...
# 4           configs\patchcore_lite\juan_baseline.yaml
# 5   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 6   outputs\juan\patchcore_lite_tuning\full_optuna...
# 7   outputs\juan\patchcore_lite_tuning\full_optuna...
# 8   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 9   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 10  outputs\juan\patchcore_lite_tuning\full_optuna...
# 11  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 12  outputs\juan\patchcore_lite_tuning\full_optuna...
# 13  outputs\juan\patchcore_lite_tuning\full_optuna...
# 14  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 15  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 16  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 17  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 18  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 19  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 20  outputs\juan\patchcore_lite_tuning\full_optuna...
# 21  outputs\juan\patchcore_lite_tuning\debug_optun...
