# %% [markdown]
# # Validation Rankings

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.common.ranking import load_rankings

# %%
rankings = load_rankings(ROOT)
rankings
# Out:
#     rank                        model_id                 experiment_name  \
# 0      1         patchcore_lite_baseline         patchcore_lite_baseline
# 1      2  patchcore_lite_juan_trial_0004  patchcore_lite_juan_trial_0004
# 2      3  patchcore_lite_juan_trial_0009  patchcore_lite_juan_trial_0009
# 3      4  patchcore_lite_juan_trial_0003  patchcore_lite_juan_trial_0003
# 4      5  patchcore_lite_juan_trial_0006  patchcore_lite_juan_trial_0006
# 5      6  patchcore_lite_juan_trial_0007  patchcore_lite_juan_trial_0007
# 6      7  patchcore_lite_juan_trial_0005  patchcore_lite_juan_trial_0005
# 7      8  patchcore_lite_juan_trial_0001  patchcore_lite_juan_trial_0001
# 8      9  patchcore_lite_juan_trial_0008  patchcore_lite_juan_trial_0008
# 9     10  patchcore_lite_juan_trial_0000  patchcore_lite_juan_trial_0000
# 10    11  patchcore_lite_juan_trial_0002  patchcore_lite_juan_trial_0002
#
#         parent_experiment owner          method    source    metric     score  \
# 0                     NaN  juan  patchcore_lite  baseline  pixel_ap  0.322563
# 1   patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.322267
# 2   patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.314869
# 3   patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.313526
# 4   patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.312060
# 5   patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.308948
# 6   patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.305698
# 7   patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.304889
# 8   patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.304730
# 9   patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.303279
# 10  patchcore_lite_tuning  juan  patchcore_lite    optuna  pixel_ap  0.300540
#
#     pixel_ap  ...  n_images  n_anomaly_pixels  validation_n_splits  \
# 0   0.322563  ...      1190           1217489                    5
# 1   0.322267  ...      1190           1217489                    5
# 2   0.314869  ...      1190           1217489                    5
# 3   0.313526  ...      1190           1217489                    5
# 4   0.312060  ...      1190           1217489                    5
# 5   0.308948  ...      1190           1217489                    5
# 6   0.305698  ...      1190           1217489                    5
# 7   0.304889  ...      1190           1217489                    5
# 8   0.304730  ...      1190           1217489                    5
# 9   0.303279  ...      1190           1217489                    5
# 10  0.300540  ...      1190           1217489                    5
#
#     validation_folds  validation_good_fraction  validation_anomaly_fraction  \
# 0                  0                      0.25                          1.0
# 1                  0                      0.25                          1.0
# 2                  0                      0.25                          1.0
# 3                  0                      0.25                          1.0
# 4                  0                      0.25                          1.0
# 5                  0                      0.25                          1.0
# 6                  0                      0.25                          1.0
# 7                  0                      0.25                          1.0
# 8                  0                      0.25                          1.0
# 9                  0                      0.25                          1.0
# 10                 0                      0.25                          1.0
#
#                                           config_path  \
# 0           configs\patchcore_lite\juan_baseline.yaml
# 1   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 2   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 3   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 4   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 5   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 6   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 7   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 8   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 9   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 10  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
#
#                                           params_json  \
# 0   {"backbone": "wide_resnet50_2", "bank_chunk_si...
# 1   {"candidate_pool_size": 4000, "coreset_fractio...
# 2   {"candidate_pool_size": 5000, "coreset_fractio...
# 3   {"candidate_pool_size": 6000, "coreset_fractio...
# 4   {"candidate_pool_size": 4000, "coreset_fractio...
# 5   {"candidate_pool_size": 5000, "coreset_fractio...
# 6   {"candidate_pool_size": 4000, "coreset_fractio...
# 7   {"candidate_pool_size": 5000, "coreset_fractio...
# 8   {"candidate_pool_size": 2000, "coreset_fractio...
# 9   {"candidate_pool_size": 5000, "coreset_fractio...
# 10  {"candidate_pool_size": 2000, "coreset_fractio...
#
#                                  notes                        created_at
# 0   PatchCore Lite baseline validation  2026-05-07T12:46:02.757469+00:00
# 1                       Optuna trial 4  2026-05-07T13:10:57.233644+00:00
# 2                       Optuna trial 9  2026-05-07T13:10:57.233644+00:00
# 3                       Optuna trial 3  2026-05-07T13:10:57.233644+00:00
# 4                       Optuna trial 6  2026-05-07T13:10:57.233644+00:00
# 5                       Optuna trial 7  2026-05-07T13:10:57.233644+00:00
# 6                       Optuna trial 5  2026-05-07T13:10:57.233644+00:00
# 7                       Optuna trial 1  2026-05-07T13:10:57.233644+00:00
# 8                       Optuna trial 8  2026-05-07T13:10:57.233644+00:00
# 9                       Optuna trial 0  2026-05-07T13:10:57.233644+00:00
# 10                      Optuna trial 2  2026-05-07T13:10:57.233644+00:00
#
# [11 rows x 23 columns]

# %%
columns = [
    "rank",
    "model_id",
    "owner",
    "method",
    "source",
    "metric",
    "score",
    "pixel_ap",
    "image_ap",
    "config_path",
]
rankings[[c for c in columns if c in rankings.columns]].head(50)
# Out:
#     rank                        model_id owner          method    source  \
# 0      1         patchcore_lite_baseline  juan  patchcore_lite  baseline
# 1      2  patchcore_lite_juan_trial_0004  juan  patchcore_lite    optuna
# 2      3  patchcore_lite_juan_trial_0009  juan  patchcore_lite    optuna
# 3      4  patchcore_lite_juan_trial_0003  juan  patchcore_lite    optuna
# 4      5  patchcore_lite_juan_trial_0006  juan  patchcore_lite    optuna
# 5      6  patchcore_lite_juan_trial_0007  juan  patchcore_lite    optuna
# 6      7  patchcore_lite_juan_trial_0005  juan  patchcore_lite    optuna
# 7      8  patchcore_lite_juan_trial_0001  juan  patchcore_lite    optuna
# 8      9  patchcore_lite_juan_trial_0008  juan  patchcore_lite    optuna
# 9     10  patchcore_lite_juan_trial_0000  juan  patchcore_lite    optuna
# 10    11  patchcore_lite_juan_trial_0002  juan  patchcore_lite    optuna
#
#       metric     score  pixel_ap  image_ap  \
# 0   pixel_ap  0.322563  0.322563  0.581574
# 1   pixel_ap  0.322267  0.322267  0.576375
# 2   pixel_ap  0.314869  0.314869  0.573433
# 3   pixel_ap  0.313526  0.313526  0.576634
# 4   pixel_ap  0.312060  0.312060  0.563686
# 5   pixel_ap  0.308948  0.308948  0.569556
# 6   pixel_ap  0.305698  0.305698  0.566320
# 7   pixel_ap  0.304889  0.304889  0.562586
# 8   pixel_ap  0.304730  0.304730  0.537169
# 9   pixel_ap  0.303279  0.303279  0.570097
# 10  pixel_ap  0.300540  0.300540  0.542079
#
#                                           config_path
# 0           configs\patchcore_lite\juan_baseline.yaml
# 1   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 2   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 3   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 4   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 5   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 6   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 7   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 8   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 9   C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
# 10  C:\Users\sjuan\Desktop\Spacespresso\outputs\ju...
